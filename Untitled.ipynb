# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

url = 'http://www.38.co.kr/html/fund/?o=v&no=1734&l=&page=1'

# %%
# params ={'startCreateDt' : startCreateDt, 'endCreateDt' : endCreateDt }
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
# <html lang="ko">
# <head>
# <title>IPO공모 > 하나금융스팩20호 공모주청약 일정, 공모주분석  - 비상장,장외주식시장 NO.1 38커뮤니케이션 </title>
# <meta http-equiv=Content-type content="text/html; charset=euc-kr">
# <meta name="keywords" content="하나금융스팩20호 공모, 하나금융스팩20호 공모 청약 일정,공모주분석, IPO, 공모일정, 상장예정, 비상장, 상장예심, 스팩, 공모주, 기업공개, 공모, 청구종목, 승인종목, 기업IR, 수요예측일정, 수용예측결과, 신규상장, 공모주청약,공모주일정,38커뮤니케이션,삼팔커뮤니케이션,38Communications,38stock,비상장매매,38스탁,38스톡,삼팔스톡,비상장,비상장주식,장외주식,장외시장,인터넷공모,프리보드,장외주식시세,장외주식 거래,장외거래,비상장주식거래,주주동호회,비상장주식시세,IPO공모주,인터넷공모주,상장,청약,공모가,">
# <meta name="description" content="하나금융스팩20호공모일정,공모주분석,공모주일정,공모주청약, (주)38커뮤니케이션(38Communicaions)은 비상장주식시장과 장외시장의 장외주식거래를 중심으로 비상장주식포털 서비스기업, IPO공모주, 인터넷공모, 프리보드, 장외주식시세 등에 관한 알찬정보와 비상장 주주동호회와 같은 비지니스 커뮤니티 등 정확하고 신뢰도 높은 정보와 서비스를 제공하고 있습니다.">
# <link rel="stylesheet" href="/common/common.css" type="text/css">
# <script type="text/javascript" src="/common/common.js"></script>
# ...

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
scope = [
'https://spreadsheets.google.com/feeds',
'https://www.googleapis.com/auth/drive',
]
json_file_name = 'C:\\Users\\User\\Downloads\\concise-isotope-289621-719ca53eca75.json'
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_file_name, scope)
gc = gspread.authorize(credentials)
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1oy5IjQGC1LxloIxeWmXA-4KMH6o0zSYPu2_NN9IQjxo/edit#gid=0'

# 스프레스시트 문서 가져오기 
doc = gc.open_by_url(spreadsheet_url)

# 시트 선택하기
worksheet = doc.worksheet('시트1')

# %%
worksheet.append_row(['new1', 'new2', 'new3', 'new4'])
# 행 추가1
# Out:
# {'spreadsheetId': '1oy5IjQGC1LxloIxeWmXA-4KMH6o0zSYPu2_NN9IQjxo',
#  'updates': {'spreadsheetId': '1oy5IjQGC1LxloIxeWmXA-4KMH6o0zSYPu2_NN9IQjxo',
#   'updatedRange': "'시트1'!A1:D1",
#   'updatedRows': 1,
#   'updatedColumns': 4,
#   'updatedCells': 4}}
